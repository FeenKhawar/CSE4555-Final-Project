# %%
import pandas as pd
import numpy as np
import pickle

# %%
with np.load("/Users/faheemkhawar/Downloads/SMPL_MALE.npz") as data:
    print(data.files)

    array1 = data["J_regressor_prior"]
    array2 = data["shapedirs"]
# Out:
# ['J_regressor_prior', 'f', 'J_regressor', 'kintree_table', 'J', 'weights_prior', 'weights', 'vert_sym_idxs', 'posedirs', 'v_template', 'shapedirs']

# %%
with open("models/basicmodel_m_lbs_10_207_0_v1.0.0.pkl", "rb") as file:
    pk_data = pickle.load(file, encoding="latin1")
# Out:
# /var/folders/3k/2xbbq8q91bnfhv_p38cc1tkm0000gn/T/ipykernel_30601/981345586.py:2: DeprecationWarning: Please import `csc_matrix` from the `scipy.sparse` namespace; the `scipy.sparse.csc` namespace is deprecated and will be removed in SciPy 2.0.0.
#   pk_data = pickle.load(file, encoding="latin1")
# /var/folders/3k/2xbbq8q91bnfhv_p38cc1tkm0000gn/T/ipykernel_30601/981345586.py:2: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   pk_data = pickle.load(file, encoding="latin1")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 with open("models/basicmodel_m_lbs_10_207_0_v1.0.0.pkl", "rb") as file:
# ----> 2     pk_data = pickle.load(file, encoding="latin1")
#
# ...

# %%
a = "models/basicmodel_m_lbs_10_207_0_v1.0.0.pkl"
pk_data = pickle.load(file, encoding="bytes")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 a = "models/basicmodel_m_lbs_10_207_0_v1.0.0.pkl"
# ----> 2 pk_data = pickle.load(file, encoding="bytes")
#
# ValueError: peek of closed file

# %%
import joblib

pk_data = joblib.load("models/basicmodel_m_lbs_10_207_0_v1.0.0.pkl")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pickle.py:1625: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   stack[-1] = func(*args)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pickle.py:1248, in _Unpickler.load(self)
#    1247         assert isinstance(key, bytes_types)
# -> 1248         dispatch[key[0]](self)
#    1249 except _Stop as stopinst:
#
# ...
